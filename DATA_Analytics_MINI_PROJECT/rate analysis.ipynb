# %%
import pandas as pd

# %%
df = pd.read_csv("CTR_Analysis.csv")

# %%
df
# Out:
#     id       full_name  age  gender          city   page_visited  \
# 0    1        John Doe   25    Male      New York       Homepage
# 1    2      Jane Smith   30  Female   Los Angeles   Product Page
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 4    5       Ahmed Ali   35    Male         Dubai       Homepage
# 5    6     Emily Davis   27  Female        Sydney   Product Page
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 8    9       David Kim   29    Male         Seoul       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 10  11     Luis Garcia   32    Male   Mexico City       Homepage
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 12  13  Hiroshi Tanaka   29    Male         Tokyo       Homepage
# ...

# %%
df.head(5)
# Out:
#    id   full_name  age  gender         city   page_visited    ad_displayed  \
# 0   1    John Doe   25    Male     New York       Homepage      Nike Shoes
# 1   2  Jane Smith   30  Female  Los Angeles   Product Page  Adidas T-Shirt
# 2   3   Raj Patel   28    Male       Mumbai       Homepage       iPhone 15
# 3   4  Sarah Khan   22  Female       London  Checkout Page     MacBook Pro
# 4   5   Ahmed Ali   35    Male        Dubai       Homepage      Samsung TV
#
#    ad_clicked  impressions  clicks   ctr  rate ($)  session_duration  \
# 0           1          100      10  10.0       0.5               120
# 1           0          200      15   7.5       0.4               180
# 2           1          150      30  20.0       1.2               300
# 3           0          250      20   8.0       0.8               220
# 4           1           90       5   5.6       0.3               100
#
#   device_type            timestamp
# 0      Mobile  2025-02-28 10:00:00
# ...

# %%
df.shape
# Out:
# (15, 15)

# %%
df.describe
# Out:
# <bound method NDFrame.describe of     id       full_name  age  gender          city   page_visited  \
# 0    1        John Doe   25    Male      New York       Homepage
# 1    2      Jane Smith   30  Female   Los Angeles   Product Page
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 4    5       Ahmed Ali   35    Male         Dubai       Homepage
# 5    6     Emily Davis   27  Female        Sydney   Product Page
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 8    9       David Kim   29    Male         Seoul       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 10  11     Luis Garcia   32    Male   Mexico City       Homepage
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 12  13  Hiroshi Tanaka   29    Male         Tokyo       Homepage
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15 entries, 0 to 14
# Data columns (total 15 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   id                15 non-null     int64
#  1   full_name         15 non-null     object
#  2   age               15 non-null     int64
#  3   gender            15 non-null     object
#  4   city              15 non-null     object
#  5   page_visited      15 non-null     object
#  6   ad_displayed      15 non-null     object
#  7   ad_clicked        15 non-null     int64
#  8   impressions       15 non-null     int64
#  9   clicks            15 non-null     int64
#  10  ctr               15 non-null     float64
#  11  rate ($)          15 non-null     float64
#  12  session_duration  15 non-null     int64
#  13  device_type       15 non-null     object
#  14  timestamp         15 non-null     object
# dtypes: float64(2), int64(6), object(7)
# memory usage: 1.9+ KB

# %%
df.isnull()
# Out:
#        id  full_name    age  gender   city  page_visited  ad_displayed  \
# 0   False      False  False   False  False         False         False
# 1   False      False  False   False  False         False         False
# 2   False      False  False   False  False         False         False
# 3   False      False  False   False  False         False         False
# 4   False      False  False   False  False         False         False
# 5   False      False  False   False  False         False         False
# 6   False      False  False   False  False         False         False
# 7   False      False  False   False  False         False         False
# 8   False      False  False   False  False         False         False
# 9   False      False  False   False  False         False         False
# 10  False      False  False   False  False         False         False
# 11  False      False  False   False  False         False         False
# ...

# %%
df.isnull().sum()
# Out:
# id                  0
# full_name           0
# age                 0
# gender              0
# city                0
# page_visited        0
# ad_displayed        0
# ad_clicked          0
# impressions         0
# clicks              0
# ctr                 0
# rate ($)            0
# session_duration    0
# device_type         0
# timestamp           0
# dtype: int64

# %%
df.describe()
# Out:
#               id        age  ad_clicked  impressions     clicks        ctr  \
# count  15.000000  15.000000   15.000000    15.000000  15.000000  15.000000
# mean    8.000000  28.666667    0.600000   158.000000  15.600000   9.860000
# std     4.472136   4.253850    0.507093    43.948021   6.874383   3.777906
# min     1.000000  22.000000    0.000000    90.000000   5.000000   5.600000
# 25%     4.500000  25.500000    0.000000   125.000000  10.000000   7.400000
# 50%     8.000000  29.000000    1.000000   160.000000  15.000000   9.000000
# 75%    11.500000  31.500000    1.000000   185.000000  20.000000  11.000000
# max    15.000000  36.000000    1.000000   250.000000  30.000000  20.000000
#
#         rate ($)  session_duration
# count  15.000000         15.000000
# mean    0.710000        218.000000
# std     0.253687         62.928531
# min     0.300000        100.000000
# 25%     0.500000        185.000000
# 50%     0.750000        220.000000
# 75%     0.875000        265.000000
# ...

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.drop_duplicates()
# Out:
#     id       full_name  age  gender          city   page_visited  \
# 0    1        John Doe   25    Male      New York       Homepage
# 1    2      Jane Smith   30  Female   Los Angeles   Product Page
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 4    5       Ahmed Ali   35    Male         Dubai       Homepage
# 5    6     Emily Davis   27  Female        Sydney   Product Page
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 8    9       David Kim   29    Male         Seoul       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 10  11     Luis Garcia   32    Male   Mexico City       Homepage
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 12  13  Hiroshi Tanaka   29    Male         Tokyo       Homepage
# ...

# %%
df.nunique()
# Out:
# id                  15
# full_name           15
# age                 14
# gender               2
# city                15
# page_visited         4
# ad_displayed        15
# ad_clicked           2
# impressions         13
# clicks              11
# ctr                 14
# rate ($)            13
# session_duration    15
# device_type          3
# timestamp           15
# dtype: int64

# %%
df.fillna(df.mean(numeric_only=True),inplace=True)

# %%
df.isnull()
# Out:
#        id  full_name    age  gender   city  page_visited  ad_displayed  \
# 0   False      False  False   False  False         False         False
# 1   False      False  False   False  False         False         False
# 2   False      False  False   False  False         False         False
# 3   False      False  False   False  False         False         False
# 4   False      False  False   False  False         False         False
# 5   False      False  False   False  False         False         False
# 6   False      False  False   False  False         False         False
# 7   False      False  False   False  False         False         False
# 8   False      False  False   False  False         False         False
# 9   False      False  False   False  False         False         False
# 10  False      False  False   False  False         False         False
# 11  False      False  False   False  False         False         False
# ...

# %%
df.dropna()
# Out:
#     id       full_name  age  gender          city   page_visited  \
# 0    1        John Doe   25    Male      New York       Homepage
# 1    2      Jane Smith   30  Female   Los Angeles   Product Page
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 4    5       Ahmed Ali   35    Male         Dubai       Homepage
# 5    6     Emily Davis   27  Female        Sydney   Product Page
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 8    9       David Kim   29    Male         Seoul       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 10  11     Luis Garcia   32    Male   Mexico City       Homepage
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 12  13  Hiroshi Tanaka   29    Male         Tokyo       Homepage
# ...

# %%
df['ad_clicked'].replace(1,2)
# Out:
# 0     2
# 1     0
# 2     2
# 3     0
# 4     2
# 5     2
# 6     0
# 7     2
# 8     2
# 9     0
# 10    2
# 11    2
# 12    0
# 13    2
# 14    0
# Name: ad_clicked, dtype: int64

# %%
df
# Out:
#     id       full_name  age  gender          city   page_visited  \
# 0    1        John Doe   25    Male      New York       Homepage
# 1    2      Jane Smith   30  Female   Los Angeles   Product Page
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 4    5       Ahmed Ali   35    Male         Dubai       Homepage
# 5    6     Emily Davis   27  Female        Sydney   Product Page
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 8    9       David Kim   29    Male         Seoul       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 10  11     Luis Garcia   32    Male   Mexico City       Homepage
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 12  13  Hiroshi Tanaka   29    Male         Tokyo       Homepage
# ...

# %%
df.drop(columns=['timestamp'])
# Out:
#     id       full_name  age  gender          city   page_visited  \
# 0    1        John Doe   25    Male      New York       Homepage
# 1    2      Jane Smith   30  Female   Los Angeles   Product Page
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 4    5       Ahmed Ali   35    Male         Dubai       Homepage
# 5    6     Emily Davis   27  Female        Sydney   Product Page
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 8    9       David Kim   29    Male         Seoul       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 10  11     Luis Garcia   32    Male   Mexico City       Homepage
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 12  13  Hiroshi Tanaka   29    Male         Tokyo       Homepage
# ...

# %%
df
# Out:
#     id       full_name  age  gender          city   page_visited  \
# 0    1        John Doe   25    Male      New York       Homepage
# 1    2      Jane Smith   30  Female   Los Angeles   Product Page
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 4    5       Ahmed Ali   35    Male         Dubai       Homepage
# 5    6     Emily Davis   27  Female        Sydney   Product Page
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 8    9       David Kim   29    Male         Seoul       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 10  11     Luis Garcia   32    Male   Mexico City       Homepage
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 12  13  Hiroshi Tanaka   29    Male         Tokyo       Homepage
# ...

# %%
df.rename(columns={'page_visited':'page_opened'})
# Out:
#     id       full_name  age  gender          city    page_opened  \
# 0    1        John Doe   25    Male      New York       Homepage
# 1    2      Jane Smith   30  Female   Los Angeles   Product Page
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 4    5       Ahmed Ali   35    Male         Dubai       Homepage
# 5    6     Emily Davis   27  Female        Sydney   Product Page
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 8    9       David Kim   29    Male         Seoul       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 10  11     Luis Garcia   32    Male   Mexico City       Homepage
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 12  13  Hiroshi Tanaka   29    Male         Tokyo       Homepage
# ...

# %%
df['clicks'] = (df['clicks'] - df['clicks'].min()) / (df['clicks'].max() - df['clicks'].min())

# %%
df
# Out:
#     id       full_name  age  gender          city   page_visited  \
# 0    1        John Doe   25    Male      New York       Homepage
# 1    2      Jane Smith   30  Female   Los Angeles   Product Page
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 4    5       Ahmed Ali   35    Male         Dubai       Homepage
# 5    6     Emily Davis   27  Female        Sydney   Product Page
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 8    9       David Kim   29    Male         Seoul       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 10  11     Luis Garcia   32    Male   Mexico City       Homepage
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 12  13  Hiroshi Tanaka   29    Male         Tokyo       Homepage
# ...

# %%
df['age']
# Out:
# 0     25
# 1     30
# 2     28
# 3     22
# 4     35
# 5     27
# 6     33
# 7     24
# 8     29
# 9     26
# 10    32
# 11    31
# 12    29
# 13    23
# 14    36
# Name: age, dtype: int64

# %%
df[['full_name','city']]
# Out:
#          full_name          city
# 0         John Doe      New York
# 1       Jane Smith   Los Angeles
# 2        Raj Patel        Mumbai
# 3       Sarah Khan        London
# 4        Ahmed Ali         Dubai
# 5      Emily Davis        Sydney
# 6      Michael Lee     Singapore
# 7     Priya Sharma     Bangalore
# 8        David Kim         Seoul
# 9      Fatima Noor       Karachi
# 10     Luis Garcia   Mexico City
# 11    Anna Ivanova        Moscow
# 12  Hiroshi Tanaka         Tokyo
# 13   Sofia Martins        Lisbon
# 14    Carlos Rojas  Buenos Aires

# %%
df[df["city"]=="New York"]
# Out:
#    id full_name  age gender      city page_visited ad_displayed  ad_clicked  \
# 0   1  John Doe   25   Male  New York     Homepage   Nike Shoes           1
#
#    impressions  clicks   ctr  rate ($)  session_duration device_type  \
# 0          100     0.2  10.0       0.5               120      Mobile
#
#              timestamp
# 0  2025-02-28 10:00:00

# %%
df[df['age']>30]
# Out:
#     id     full_name  age  gender          city   page_visited  \
# 4    5     Ahmed Ali   35    Male         Dubai       Homepage
# 6    7   Michael Lee   33    Male     Singapore       Homepage
# 10  11   Luis Garcia   32    Male   Mexico City       Homepage
# 11  12  Anna Ivanova   31  Female        Moscow  Checkout Page
# 14  15  Carlos Rojas   36    Male  Buenos Aires       Homepage
#
#       ad_displayed  ad_clicked  impressions  clicks   ctr  rate ($)  \
# 4       Samsung TV           1           90    0.00   5.6      0.30
# 6      Dell Laptop           0          170    0.20   5.9      0.45
# 10     Apple Watch           1          160    0.68  13.8      1.00
# 11    Canon Camera           1          120    0.28  10.0      0.80
# 14  Samsung Tablet           0          190    0.60  10.5      0.95
#
#     session_duration device_type            timestamp
# 4                100      Mobile  2025-02-28 10:20:00
# 6                190     Desktop  2025-02-28 10:30:00
# ...

# %%
df.sort_values(by='age')
# Out:
#     id       full_name  age  gender          city   page_visited  \
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 13  14   Sofia Martins   23  Female        Lisbon   Product Page
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 0    1        John Doe   25    Male      New York       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 5    6     Emily Davis   27  Female        Sydney   Product Page
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 8    9       David Kim   29    Male         Seoul       Homepage
# 12  13  Hiroshi Tanaka   29    Male         Tokyo       Homepage
# 1    2      Jane Smith   30  Female   Los Angeles   Product Page
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 10  11     Luis Garcia   32    Male   Mexico City       Homepage
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# ...

# %%
df.sort_values(by='city')
# Out:
#     id       full_name  age  gender          city   page_visited  \
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 14  15    Carlos Rojas   36    Male  Buenos Aires       Homepage
# 4    5       Ahmed Ali   35    Male         Dubai       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 13  14   Sofia Martins   23  Female        Lisbon   Product Page
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 1    2      Jane Smith   30  Female   Los Angeles   Product Page
# 10  11     Luis Garcia   32    Male   Mexico City       Homepage
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 0    1        John Doe   25    Male      New York       Homepage
# 8    9       David Kim   29    Male         Seoul       Homepage
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# ...

# %%
df.sort_values(by="rate ($)",ascending=False)
# Out:
#     id       full_name  age  gender          city   page_visited  \
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 10  11     Luis Garcia   32    Male   Mexico City       Homepage
# 14  15    Carlos Rojas   36    Male  Buenos Aires       Homepage
# 5    6     Emily Davis   27  Female        Sydney   Product Page
# 8    9       David Kim   29    Male         Seoul       Homepage
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 12  13  Hiroshi Tanaka   29    Male         Tokyo       Homepage
# 13  14   Sofia Martins   23  Female        Lisbon   Product Page
# 0    1        John Doe   25    Male      New York       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# ...

# %%
df.sort_values(by='age').head(3)
# Out:
#     id      full_name  age  gender       city   page_visited ad_displayed  \
# 3    4     Sarah Khan   22  Female     London  Checkout Page  MacBook Pro
# 13  14  Sofia Martins   23  Female     Lisbon   Product Page   HP Printer
# 7    8   Priya Sharma   24  Female  Bangalore      Cart Page   Smartwatch
#
#     ad_clicked  impressions  clicks   ctr  rate ($)  session_duration  \
# 3            0          250     0.6   8.0      0.80               220
# 13           1          140     0.2   7.1      0.55               200
# 7            1          130     0.4  11.5      0.75               260
#
#    device_type            timestamp
# 3      Desktop  2025-02-28 10:15:00
# 13      Tablet  2025-02-28 11:05:00
# 7       Mobile  2025-02-28 10:35:00

# %%
df.rename(columns={'city':'Location'})
# Out:
#     id       full_name  age  gender      Location   page_visited  \
# 0    1        John Doe   25    Male      New York       Homepage
# 1    2      Jane Smith   30  Female   Los Angeles   Product Page
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 4    5       Ahmed Ali   35    Male         Dubai       Homepage
# 5    6     Emily Davis   27  Female        Sydney   Product Page
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 8    9       David Kim   29    Male         Seoul       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 10  11     Luis Garcia   32    Male   Mexico City       Homepage
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 12  13  Hiroshi Tanaka   29    Male         Tokyo       Homepage
# ...

# %%
df.rename(columns={'age':'Person_Age'})
# Out:
#     id       full_name  Person_Age  gender          city   page_visited  \
# 0    1        John Doe          25    Male      New York       Homepage
# 1    2      Jane Smith          30  Female   Los Angeles   Product Page
# 2    3       Raj Patel          28    Male        Mumbai       Homepage
# 3    4      Sarah Khan          22  Female        London  Checkout Page
# 4    5       Ahmed Ali          35    Male         Dubai       Homepage
# 5    6     Emily Davis          27  Female        Sydney   Product Page
# 6    7     Michael Lee          33    Male     Singapore       Homepage
# 7    8    Priya Sharma          24  Female     Bangalore      Cart Page
# 8    9       David Kim          29    Male         Seoul       Homepage
# 9   10     Fatima Noor          26  Female       Karachi   Product Page
# 10  11     Luis Garcia          32    Male   Mexico City       Homepage
# 11  12    Anna Ivanova          31  Female        Moscow  Checkout Page
# ...

# %%
df.rename(columns={'age': 'Age_Years', 'city': 'City_Name'})
# Out:
#     id       full_name  Age_Years  gender     City_Name   page_visited  \
# 0    1        John Doe         25    Male      New York       Homepage
# 1    2      Jane Smith         30  Female   Los Angeles   Product Page
# 2    3       Raj Patel         28    Male        Mumbai       Homepage
# 3    4      Sarah Khan         22  Female        London  Checkout Page
# 4    5       Ahmed Ali         35    Male         Dubai       Homepage
# 5    6     Emily Davis         27  Female        Sydney   Product Page
# 6    7     Michael Lee         33    Male     Singapore       Homepage
# 7    8    Priya Sharma         24  Female     Bangalore      Cart Page
# 8    9       David Kim         29    Male         Seoul       Homepage
# 9   10     Fatima Noor         26  Female       Karachi   Product Page
# 10  11     Luis Garcia         32    Male   Mexico City       Homepage
# 11  12    Anna Ivanova         31  Female        Moscow  Checkout Page
# ...

# %%
df['age'].mean()
# Out:
# 28.666666666666668

# %%
df['clicks'].sum()
# Out:
# 6.360000000000001

# %%
df['city'].sum()
# Out:
# 'New YorkLos AngelesMumbaiLondonDubaiSydneySingaporeBangaloreSeoulKarachiMexico CityMoscowTokyoLisbonBuenos Aires'

# %%
df['age'].max()
# Out:
# 36

# %%
df['rate ($)'].min()
# Out:
# 0.3

# %%
import matplotlib.pyplot as plt

# %%
plt.subplot(2, 3, 1)
plt.bar(df["city"], df["age"],color='blue')
plt.xticks(rotation=90)
plt.title("Bar Plot: City vs. Age")
# Out:
# Text(0.5, 1.0, 'Bar Plot: City vs. Age')

# %%
plt.subplot(2, 3, 2)
plt.plot(df.index, df["age"], marker='o', linestyle='-', color='green')
plt.xlabel("Index")
plt.ylabel("Age")
plt.title("Line Plot: Age over Index")
# Out:
# Text(0.5, 1.0, 'Line Plot: Age over Index')

# %%
plt.subplot(2, 3, 3)
plt.hist(df["age"], bins=8, color='skyblue', edgecolor='black')
plt.xlabel("Age")
plt.ylabel("Frequency")
plt.title("Histogram: Age Distribution")
# Out:
# Text(0.5, 1.0, 'Histogram: Age Distribution')

# %%
plt.subplot(2, 3, 5)
plt.scatter(df["age"], df["rate ($)"], color='red')
plt.xlabel("Age")
plt.ylabel("Price")
plt.title("Scatter Plot: Age vs. Price")
# Out:
# Text(0.5, 1.0, 'Scatter Plot: Age vs. Price')

# %%
plt.subplot(2, 3, 4)
city_counts = df["city"].value_counts()
plt.pie(city_counts, labels=city_counts.index, autopct='%1.1f%%', startangle=140)
plt.title("Pie Chart: City Distribution")
# Out:
# Text(0.5, 1.0, 'Pie Chart: City Distribution')

# %%
 df['city'].str.lower()
# Out:
# 0         new york
# 1      los angeles
# 2           mumbai
# 3           london
# 4            dubai
# 5           sydney
# 6        singapore
# 7        bangalore
# 8            seoul
# 9          karachi
# 10     mexico city
# 11          moscow
# 12           tokyo
# 13          lisbon
# 14    buenos aires
# Name: city, dtype: object

# %%
df
# Out:
#     id       full_name  age  gender          city   page_visited  \
# 0    1        John Doe   25    Male      New York       Homepage
# 1    2      Jane Smith   30  Female   Los Angeles   Product Page
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 4    5       Ahmed Ali   35    Male         Dubai       Homepage
# 5    6     Emily Davis   27  Female        Sydney   Product Page
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 8    9       David Kim   29    Male         Seoul       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 10  11     Luis Garcia   32    Male   Mexico City       Homepage
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 12  13  Hiroshi Tanaka   29    Male         Tokyo       Homepage
# ...

# %%
df[['First Name', 'Last Name']] = df['full_name'].str.split(' ', n=1, expand=True)

# %%
df
# Out:
#     id       full_name  age  gender          city   page_visited  \
# 0    1        John Doe   25    Male      New York       Homepage
# 1    2      Jane Smith   30  Female   Los Angeles   Product Page
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 4    5       Ahmed Ali   35    Male         Dubai       Homepage
# 5    6     Emily Davis   27  Female        Sydney   Product Page
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 8    9       David Kim   29    Male         Seoul       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 10  11     Luis Garcia   32    Male   Mexico City       Homepage
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 12  13  Hiroshi Tanaka   29    Male         Tokyo       Homepage
# ...

# %%
df['full_name'] = df['First Name'] + ' ' + df['Last Name']

# %%
df
# Out:
#     id       full_name  age  gender          city   page_visited  \
# 0    1        John Doe   25    Male      New York       Homepage
# 1    2      Jane Smith   30  Female   Los Angeles   Product Page
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 4    5       Ahmed Ali   35    Male         Dubai       Homepage
# 5    6     Emily Davis   27  Female        Sydney   Product Page
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 8    9       David Kim   29    Male         Seoul       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 10  11     Luis Garcia   32    Male   Mexico City       Homepage
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 12  13  Hiroshi Tanaka   29    Male         Tokyo       Homepage
# ...

# %%
df['city'] = df['city'].str.replace(' ', '_')
df
# Out:
#     id       full_name  age  gender          city   page_visited  \
# 0    1        John Doe   25    Male      New_York       Homepage
# 1    2      Jane Smith   30  Female   Los_Angeles   Product Page
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 4    5       Ahmed Ali   35    Male         Dubai       Homepage
# 5    6     Emily Davis   27  Female        Sydney   Product Page
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 8    9       David Kim   29    Male         Seoul       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 10  11     Luis Garcia   32    Male   Mexico_City       Homepage
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 12  13  Hiroshi Tanaka   29    Male         Tokyo       Homepage
# ...

# %%
df.iloc[0]
# Out:
# id                                    1
# full_name                      John Doe
# age                                  25
# gender                             Male
# city                           New_York
# page_visited                   Homepage
# ad_displayed                 Nike Shoes
# ad_clicked                            1
# impressions                         100
# clicks                              0.2
# ctr                                10.0
# rate ($)                            0.5
# session_duration                    120
# device_type                      Mobile
# timestamp           2025-02-28 10:00:00
# First Name                         John
# Last Name                           Doe
# Name: 0, dtype: object

# %%
df.iloc[-3]
# Out:
# id                                   13
# full_name                Hiroshi Tanaka
# age                                  29
# gender                             Male
# city                              Tokyo
# page_visited                   Homepage
# ad_displayed               Xbox Console
# ad_clicked                            0
# impressions                         180
# clicks                             0.36
# ctr                                 7.8
# rate ($)                            0.7
# session_duration                    230
# device_type                      Mobile
# timestamp           2025-02-28 11:00:00
# First Name                      Hiroshi
# Last Name                        Tanaka
# Name: 12, dtype: object

# %%
df.iloc[:5,:3]
# Out:
#    id   full_name  age
# 0   1    John Doe   25
# 1   2  Jane Smith   30
# 2   3   Raj Patel   28
# 3   4  Sarah Khan   22
# 4   5   Ahmed Ali   35

# %%
df.iloc[:,1:3]
# Out:
#          full_name  age
# 0         John Doe   25
# 1       Jane Smith   30
# 2        Raj Patel   28
# 3       Sarah Khan   22
# 4        Ahmed Ali   35
# 5      Emily Davis   27
# 6      Michael Lee   33
# 7     Priya Sharma   24
# 8        David Kim   29
# 9      Fatima Noor   26
# 10     Luis Garcia   32
# 11    Anna Ivanova   31
# 12  Hiroshi Tanaka   29
# 13   Sofia Martins   23
# 14    Carlos Rojas   36

# %%
df.iloc[3,1]
# Out:
# 'Sarah Khan'

# %%
df.iloc[1:5,0:4]
# Out:
#    id   full_name  age  gender
# 1   2  Jane Smith   30  Female
# 2   3   Raj Patel   28    Male
# 3   4  Sarah Khan   22  Female
# 4   5   Ahmed Ali   35    Male

# %%
df.loc[df['full_name']=="Raj Patel"]
# Out:
#    id  full_name  age gender    city page_visited ad_displayed  ad_clicked  \
# 2   3  Raj Patel   28   Male  Mumbai     Homepage    iPhone 15           1
#
#    impressions  clicks   ctr  rate ($)  session_duration device_type  \
# 2          150     1.0  20.0       1.2               300      Tablet
#
#              timestamp First Name Last Name
# 2  2025-02-28 10:10:00        Raj     Patel

# %%
df.loc[df['age']>30]
# Out:
#     id     full_name  age  gender          city   page_visited  \
# 4    5     Ahmed Ali   35    Male         Dubai       Homepage
# 6    7   Michael Lee   33    Male     Singapore       Homepage
# 10  11   Luis Garcia   32    Male   Mexico_City       Homepage
# 11  12  Anna Ivanova   31  Female        Moscow  Checkout Page
# 14  15  Carlos Rojas   36    Male  Buenos_Aires       Homepage
#
#       ad_displayed  ad_clicked  impressions  clicks   ctr  rate ($)  \
# 4       Samsung TV           1           90    0.00   5.6      0.30
# 6      Dell Laptop           0          170    0.20   5.9      0.45
# 10     Apple Watch           1          160    0.68  13.8      1.00
# 11    Canon Camera           1          120    0.28  10.0      0.80
# 14  Samsung Tablet           0          190    0.60  10.5      0.95
#
#     session_duration device_type            timestamp First Name Last Name
# 4                100      Mobile  2025-02-28 10:20:00      Ahmed       Ali
# ...

# %%
df.loc[df['city']=="Dubai"]
# Out:
#    id  full_name  age gender   city page_visited ad_displayed  ad_clicked  \
# 4   5  Ahmed Ali   35   Male  Dubai     Homepage   Samsung TV           1
#
#    impressions  clicks  ctr  rate ($)  session_duration device_type  \
# 4           90     0.0  5.6       0.3               100      Mobile
#
#              timestamp First Name Last Name
# 4  2025-02-28 10:20:00      Ahmed       Ali

# %%
df.loc[5, ['full_name', 'city']]
# Out:
# full_name    Emily Davis
# city              Sydney
# Name: 5, dtype: object

# %%
import numpy as np

# %%
df.replace(7.99,8)
# Out:
#     id       full_name  age  gender          city   page_visited  \
# 0    1        John Doe   25    Male      New_York       Homepage
# 1    2      Jane Smith   30  Female   Los_Angeles   Product Page
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 4    5       Ahmed Ali   35    Male         Dubai       Homepage
# 5    6     Emily Davis   27  Female        Sydney   Product Page
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 8    9       David Kim   29    Male         Seoul       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 10  11     Luis Garcia   32    Male   Mexico_City       Homepage
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 12  13  Hiroshi Tanaka   29    Male         Tokyo       Homepage
# ...

# %%
df['gender'].replace({'Male': 1, 'Female': 0})
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_19816\1400260860.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['gender'].replace({'Male': 1, 'Female': 0})
# 0     1
# 1     0
# 2     1
# 3     0
# 4     1
# 5     0
# 6     1
# 7     0
# 8     1
# 9     0
# 10    1
# 11    0
# 12    1
# 13    0
# 14    1
# Name: gender, dtype: int64

# %%
df['ad_clicked'].replace({'1': 'Yes', '0': 'No'})
# Out:
# 0     1
# 1     0
# 2     1
# 3     0
# 4     1
# 5     1
# 6     0
# 7     1
# 8     1
# 9     0
# 10    1
# 11    1
# 12    0
# 13    1
# 14    0
# Name: ad_clicked, dtype: int64

# %%
df
# Out:
#     id       full_name  age  gender          city   page_visited  \
# 0    1        John Doe   25    Male      New_York       Homepage
# 1    2      Jane Smith   30  Female   Los_Angeles   Product Page
# 2    3       Raj Patel   28    Male        Mumbai       Homepage
# 3    4      Sarah Khan   22  Female        London  Checkout Page
# 4    5       Ahmed Ali   35    Male         Dubai       Homepage
# 5    6     Emily Davis   27  Female        Sydney   Product Page
# 6    7     Michael Lee   33    Male     Singapore       Homepage
# 7    8    Priya Sharma   24  Female     Bangalore      Cart Page
# 8    9       David Kim   29    Male         Seoul       Homepage
# 9   10     Fatima Noor   26  Female       Karachi   Product Page
# 10  11     Luis Garcia   32    Male   Mexico_City       Homepage
# 11  12    Anna Ivanova   31  Female        Moscow  Checkout Page
# 12  13  Hiroshi Tanaka   29    Male         Tokyo       Homepage
# ...

# %%
df['ctr'].replace(8.0, np.nan)
# Out:
# 0     10.0
# 1      7.5
# 2     20.0
# 3      NaN
# 4      5.6
# 5     13.9
# 6      5.9
# 7     11.5
# 8      9.0
# 9      7.3
# 10    13.8
# 11    10.0
# 12     7.8
# 13     7.1
# 14    10.5
# Name: ctr, dtype: float64

# %%
df.set_index('full_name', inplace=True)
df
# Out:
#                 id  age  gender          city   page_visited     ad_displayed  \
# full_name
# John Doe         1   25    Male      New_York       Homepage       Nike Shoes
# Jane Smith       2   30  Female   Los_Angeles   Product Page   Adidas T-Shirt
# Raj Patel        3   28    Male        Mumbai       Homepage        iPhone 15
# Sarah Khan       4   22  Female        London  Checkout Page      MacBook Pro
# Ahmed Ali        5   35    Male         Dubai       Homepage       Samsung TV
# Emily Davis      6   27  Female        Sydney   Product Page  Sony Headphones
# Michael Lee      7   33    Male     Singapore       Homepage      Dell Laptop
# Priya Sharma     8   24  Female     Bangalore      Cart Page       Smartwatch
# David Kim        9   29    Male         Seoul       Homepage     Gaming Mouse
# Fatima Noor     10   26  Female       Karachi   Product Page      JBL Speaker
# Luis Garcia     11   32    Male   Mexico_City       Homepage      Apple Watch
# ...

# %%
df.reset_index(inplace=True)
df
# Out:
#          full_name  id  age  gender          city   page_visited  \
# 0         John Doe   1   25    Male      New_York       Homepage
# 1       Jane Smith   2   30  Female   Los_Angeles   Product Page
# 2        Raj Patel   3   28    Male        Mumbai       Homepage
# 3       Sarah Khan   4   22  Female        London  Checkout Page
# 4        Ahmed Ali   5   35    Male         Dubai       Homepage
# 5      Emily Davis   6   27  Female        Sydney   Product Page
# 6      Michael Lee   7   33    Male     Singapore       Homepage
# 7     Priya Sharma   8   24  Female     Bangalore      Cart Page
# 8        David Kim   9   29    Male         Seoul       Homepage
# 9      Fatima Noor  10   26  Female       Karachi   Product Page
# 10     Luis Garcia  11   32    Male   Mexico_City       Homepage
# 11    Anna Ivanova  12   31  Female        Moscow  Checkout Page
# 12  Hiroshi Tanaka  13   29    Male         Tokyo       Homepage
# ...

# %%
df.set_index(['city', 'age'], inplace=True)
df
# Out:
#                        full_name  id  gender   page_visited     ad_displayed  \
# city         age
# New_York     25         John Doe   1    Male       Homepage       Nike Shoes
# Los_Angeles  30       Jane Smith   2  Female   Product Page   Adidas T-Shirt
# Mumbai       28        Raj Patel   3    Male       Homepage        iPhone 15
# London       22       Sarah Khan   4  Female  Checkout Page      MacBook Pro
# Dubai        35        Ahmed Ali   5    Male       Homepage       Samsung TV
# Sydney       27      Emily Davis   6  Female   Product Page  Sony Headphones
# Singapore    33      Michael Lee   7    Male       Homepage      Dell Laptop
# Bangalore    24     Priya Sharma   8  Female      Cart Page       Smartwatch
# Seoul        29        David Kim   9    Male       Homepage     Gaming Mouse
# Karachi      26      Fatima Noor  10  Female   Product Page      JBL Speaker
# Mexico_City  32      Luis Garcia  11    Male       Homepage      Apple Watch
# ...

# %%
df.reset_index(['city', 'age'], inplace=True)
df
# Out:
#             city  age       full_name  id  gender   page_visited  \
# 0       New_York   25        John Doe   1    Male       Homepage
# 1    Los_Angeles   30      Jane Smith   2  Female   Product Page
# 2         Mumbai   28       Raj Patel   3    Male       Homepage
# 3         London   22      Sarah Khan   4  Female  Checkout Page
# 4          Dubai   35       Ahmed Ali   5    Male       Homepage
# 5         Sydney   27     Emily Davis   6  Female   Product Page
# 6      Singapore   33     Michael Lee   7    Male       Homepage
# 7      Bangalore   24    Priya Sharma   8  Female      Cart Page
# 8          Seoul   29       David Kim   9    Male       Homepage
# 9        Karachi   26     Fatima Noor  10  Female   Product Page
# 10   Mexico_City   32     Luis Garcia  11    Male       Homepage
# 11        Moscow   31    Anna Ivanova  12  Female  Checkout Page
# 12         Tokyo   29  Hiroshi Tanaka  13    Male       Homepage
# ...

# %%
df
# Out:
#               age       full_name  id  gender   page_visited     ad_displayed  \
# city
# New_York       25        John Doe   1    Male       Homepage       Nike Shoes
# Los_Angeles    30      Jane Smith   2  Female   Product Page   Adidas T-Shirt
# Mumbai         28       Raj Patel   3    Male       Homepage        iPhone 15
# London         22      Sarah Khan   4  Female  Checkout Page      MacBook Pro
# Dubai          35       Ahmed Ali   5    Male       Homepage       Samsung TV
# Sydney         27     Emily Davis   6  Female   Product Page  Sony Headphones
# Singapore      33     Michael Lee   7    Male       Homepage      Dell Laptop
# Bangalore      24    Priya Sharma   8  Female      Cart Page       Smartwatch
# Seoul          29       David Kim   9    Male       Homepage     Gaming Mouse
# Karachi        26     Fatima Noor  10  Female   Product Page      JBL Speaker
# Mexico_City    32     Luis Garcia  11    Male       Homepage      Apple Watch
# ...

# %%
df.loc['Lisbon']
# Out:
# age                                  23
# full_name                 Sofia Martins
# id                                   14
# gender                           Female
# page_visited               Product Page
# ad_displayed                 HP Printer
# ad_clicked                            1
# impressions                         140
# clicks                              0.2
# ctr                                 7.1
# rate ($)                           0.55
# session_duration                    200
# device_type                      Tablet
# timestamp           2025-02-28 11:05:00
# First Name                        Sofia
# Last Name                       Martins
# Name: Lisbon, dtype: object

# %%
df.index.dtype
df.index.is_unique
# Out:
# True

# %%
df.groupby('city')['age'].mean()
# Out:
# city
# Bangalore       24.0
# Buenos_Aires    36.0
# Dubai           35.0
# Karachi         26.0
# Lisbon          23.0
# London          22.0
# Los_Angeles     30.0
# Mexico_City     32.0
# Moscow          31.0
# Mumbai          28.0
# New_York        25.0
# Seoul           29.0
# Singapore       33.0
# Sydney          27.0
# Tokyo           29.0
# Name: age, dtype: float64

# %%
df.groupby('age')['gender'].count()
# Out:
# age
# 22    1
# 23    1
# 24    1
# 25    1
# 26    1
# 27    1
# 28    1
# 29    2
# 30    1
# 31    1
# 32    1
# 33    1
# 35    1
# 36    1
# Name: gender, dtype: int64

# %%
df.groupby('age')['rate ($)'].sum()
# Out:
# age
# 22    0.80
# 23    0.55
# 24    0.75
# 25    0.50
# 26    0.50
# 27    0.90
# 28    1.20
# 29    1.55
# 30    0.40
# 31    0.80
# 32    1.00
# 33    0.45
# 35    0.30
# 36    0.95
# Name: rate ($), dtype: float64

# %%
df.groupby('city')['age'].max()
# Out:
# city
# Bangalore       24
# Buenos_Aires    36
# Dubai           35
# Karachi         26
# Lisbon          23
# London          22
# Los_Angeles     30
# Mexico_City     32
# Moscow          31
# Mumbai          28
# New_York        25
# Seoul           29
# Singapore       33
# Sydney          27
# Tokyo           29
# Name: age, dtype: int64

# %%
df.groupby('gender')['rate ($)'].agg(['sum', 'mean', 'count'])
# Out:
#          sum      mean  count
# gender
# Female  4.70  0.671429      7
# Male    5.95  0.743750      8

# %%
df.groupby('city')['age'].agg(['mean', 'median'])
# Out:
#               mean  median
# city
# Bangalore     24.0    24.0
# Buenos_Aires  36.0    36.0
# Dubai         35.0    35.0
# Karachi       26.0    26.0
# Lisbon        23.0    23.0
# London        22.0    22.0
# Los_Angeles   30.0    30.0
# Mexico_City   32.0    32.0
# Moscow        31.0    31.0
# Mumbai        28.0    28.0
# New_York      25.0    25.0
# Seoul         29.0    29.0
# Singapore     33.0    33.0
# Sydney        27.0    27.0
# Tokyo         29.0    29.0

# %%
df
# Out:
#               age       full_name  id  gender   page_visited     ad_displayed  \
# city
# New_York       25        John Doe   1    Male       Homepage       Nike Shoes
# Los_Angeles    30      Jane Smith   2  Female   Product Page   Adidas T-Shirt
# Mumbai         28       Raj Patel   3    Male       Homepage        iPhone 15
# London         22      Sarah Khan   4  Female  Checkout Page      MacBook Pro
# Dubai          35       Ahmed Ali   5    Male       Homepage       Samsung TV
# Sydney         27     Emily Davis   6  Female   Product Page  Sony Headphones
# Singapore      33     Michael Lee   7    Male       Homepage      Dell Laptop
# Bangalore      24    Priya Sharma   8  Female      Cart Page       Smartwatch
# Seoul          29       David Kim   9    Male       Homepage     Gaming Mouse
# Karachi        26     Fatima Noor  10  Female   Product Page      JBL Speaker
# Mexico_City    32     Luis Garcia  11    Male       Homepage      Apple Watch
# ...

# %%
df.groupby('page_visited')['rate ($)'].agg(['min', 'max'])
# Out:
#                 min   max
# page_visited
# Cart Page      0.75  0.75
# Checkout Page  0.80  0.80
# Homepage       0.30  1.20
# Product Page   0.40  0.90

# %%
df.groupby('city')['age'].agg(lambda x: x.max() - x.min())
# Out:
# city
# Bangalore       0
# Buenos_Aires    0
# Dubai           0
# Karachi         0
# Lisbon          0
# London          0
# Los_Angeles     0
# Mexico_City     0
# Moscow          0
# Mumbai          0
# New_York        0
# Seoul           0
# Singapore       0
# Sydney          0
# Tokyo           0
# Name: age, dtype: int64

# %%
df
# Out:
#               age       full_name  id  gender   page_visited     ad_displayed  \
# city
# New_York       25        John Doe   1    Male       Homepage       Nike Shoes
# Los_Angeles    30      Jane Smith   2  Female   Product Page   Adidas T-Shirt
# Mumbai         28       Raj Patel   3    Male       Homepage        iPhone 15
# London         22      Sarah Khan   4  Female  Checkout Page      MacBook Pro
# Dubai          35       Ahmed Ali   5    Male       Homepage       Samsung TV
# Sydney         27     Emily Davis   6  Female   Product Page  Sony Headphones
# Singapore      33     Michael Lee   7    Male       Homepage      Dell Laptop
# Bangalore      24    Priya Sharma   8  Female      Cart Page       Smartwatch
# Seoul          29       David Kim   9    Male       Homepage     Gaming Mouse
# Karachi        26     Fatima Noor  10  Female   Product Page      JBL Speaker
# Mexico_City    32     Luis Garcia  11    Male       Homepage      Apple Watch
# ...

# %%
df.groupby('page_visited').agg({'ad_clicked': 'mean', 'impressions': 'sum'})
# Out:
#                ad_clicked  impressions
# page_visited
# Cart Page           1.000          130
# Checkout Page       0.500          370
# Homepage            0.625         1240
# Product Page        0.500          630

# %%
pip install faker
# Out:
# ...
#    ---------------------------------------- 0.0/1.9 MB ? eta -:--:--
#    ---------------------------------------- 1.9/1.9 MB 17.8 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import random
import faker
from datetime import datetime

# %%
fake=faker.Faker()
data={
    "name" :[fake.name() for _ in range(100)],
    "address" : [fake.address() for _ in range(100)],
    "date" : [fake.date_between(start_date="-30y", end_date="today") for _ in range(100)]
}

# %%
table=pd.DataFrame(data)
table
# Out:
#                name                                            address  \
# 0   Anthony Richard        998 Hanson Views\nMartinezchester, PR 83295
# 1       Darius Mora         1088 Castillo Valleys\nPort Lisa, MO 56089
# 2     Daniel Monroe             219 Mayer Canyon\nNew Victor, NM 80583
# 3     Mark Thompson  12915 Reyes Bridge Suite 752\nWest Ryanburgh, ...
# 4    Crystal Abbott  96010 Johnston Tunnel Suite 449\nSouth Christo...
# ..              ...                                                ...
# 95     Kelly Howell                   Unit 0911 Box 9996\nDPO AE 34824
# 96     Ray Campbell        5573 Price Skyway\nGriffinchester, MP 48014
# 97     Sandra Grant               028 Carolyn Mills\nKimbury, MA 54353
# 98      Sara Walker             955 Wilson Crest\nWalterside, WA 53741
# 99     Jessica Boyd                   Unit 6382 Box 1878\nDPO AP 93666
#
#           date
# 0   2007-08-30
# 1   1999-03-17
# 2   2020-05-30
# 3   2000-07-02
# 4   1996-02-27
# ..         ...
# ...

# %%
Name = {"Name": [fake.name() for _ in range(20)]}
Name= pd.DataFrame(Name)
Name
# Out:
#                   Name
# 0       James Gonzalez
# 1             Roy Cook
# 2         Michael Luna
# 3     Heather Mckenzie
# 4      Joseph Thompson
# 5       Michael Wagner
# 6         Donald Booth
# 7     Charles Martinez
# 8      Brandon Collins
# 9       Michael Castro
# 10       Victor Church
# 11       Corey Johnson
# 12  Benjamin Wilkinson
# 13          Rose Smith
# 14      Deborah Chavez
# 15         David Smith
# 16      Nathaniel King
# 17           Mary Paul
# 18         Leah Greene
# 19     Gwendolyn Moore

# %%
Name["Email"] = [fake.email() for _ in range(20)]
Name
# Out:
#                   Name                          Email
# 0       James Gonzalez        ryancoleman@example.org
# 1             Roy Cook         kristincox@example.com
# 2         Michael Luna        brownrobert@example.org
# 3     Heather Mckenzie             xbrown@example.com
# 4      Joseph Thompson       johnsontracy@example.org
# 5       Michael Wagner    castillocassidy@example.net
# 6         Donald Booth        alexander28@example.net
# 7     Charles Martinez   ewingchristopher@example.org
# 8      Brandon Collins         derekmoore@example.net
# 9       Michael Castro           ehoffman@example.com
# 10       Victor Church            donna45@example.net
# 11       Corey Johnson         mollyfoley@example.net
# 12  Benjamin Wilkinson  hernandezjonathan@example.org
# 13          Rose Smith        ericrodgers@example.com
# 14      Deborah Chavez   monicavalenzuela@example.net
# 15         David Smith       kristineowen@example.com
# ...

# %%
Name["Date_of_Birth"] = [fake.date_of_birth(minimum_age=18, maximum_age=80) for _ in range(20)]
Name["Age"] = Name["Date_of_Birth"].apply(lambda dob: datetime.now().year - dob.year)
Name
# Out:
#                   Name                          Email Date_of_Birth  Age
# 0       James Gonzalez        ryancoleman@example.org    1984-07-12   41
# 1             Roy Cook         kristincox@example.com    1987-07-02   38
# 2         Michael Luna        brownrobert@example.org    1972-04-24   53
# 3     Heather Mckenzie             xbrown@example.com    1957-02-05   68
# 4      Joseph Thompson       johnsontracy@example.org    1975-11-13   50
# 5       Michael Wagner    castillocassidy@example.net    1969-03-22   56
# 6         Donald Booth        alexander28@example.net    1989-04-28   36
# 7     Charles Martinez   ewingchristopher@example.org    1998-08-24   27
# 8      Brandon Collins         derekmoore@example.net    1994-10-22   31
# 9       Michael Castro           ehoffman@example.com    1986-09-20   39
# 10       Victor Church            donna45@example.net    1999-09-01   26
# 11       Corey Johnson         mollyfoley@example.net    1998-12-10   27
# ...

# %%
products = {
    "Product_Name": [fake.word() for _ in range(20)],
    "Price": [round(fake.random_number(digits=2) + fake.random.random(), 2) for _ in range(20)],
}

# %%
products = pd.DataFrame(products)
products
# Out:
#    Product_Name  Price
# 0       federal  21.25
# 1          name  41.02
# 2        doctor  58.18
# 3          road  47.40
# 4       machine  42.26
# 5         final  38.42
# 6       present  34.44
# 7           lot  84.65
# 8        beyond  81.78
# 9          feel  36.12
# 10       option  19.22
# 11     movement   5.93
# 12      natural  98.24
# 13         what  58.20
# 14        sound  60.76
# 15     personal  58.16
# 16        again  30.57
# 17        adult  34.55
# 18      clearly   9.68
# 19          put  16.01

# %%
Info= pd.DataFrame({
    "Name": [fake.name() for _ in range(20)],
    "City": [fake.city() for _ in range(20)],
    "Phone Number": [fake.phone_number() for _ in range(20)]
})

# %%
Info= pd.DataFrame(Info)
Info
# Out:
#                    Name               City           Phone Number
# 0          Steve Butler          North Amy       354-729-0839x605
# 1          Tammy Miller    New Kimberlyton      (815)381-4006x938
# 2         Paul Davidson       West William      (539)404-8523x184
# 3        Miguel Bentley       Port Rebecca     827-670-4226x22627
# 4           Wendy Davis         Port Kelly     599-845-0066x10552
# 5         Zachary Yates  South Patrickport    (528)392-8457x35131
# 6        Steven Marquez          Caroltown           528-650-2366
# 7         Shannon Grant        Lake Daniel       655-461-7161x616
# 8       Rebecca Nichols       North Joshua           475-263-0580
# 9            Kevin Holt          Brownside      (800)586-5291x646
# 10        Michelle Duke         North Sara      990.236.1412x3245
# 11       Jeremy Hancock      Lake Johntown  +1-202-991-3131x18382
# 12         Edwin Bailey          West Tara       837.205.5446x536
# ...

# %%
prod= pd.DataFrame({
    'Product_ID': [1, 2, 3, 4],
    'Product_Name': ['A', 'B', 'C', 'D']
})

# %%
product = pd.DataFrame({
    "Product_ID": [2, 3, 4], 
    "Price": [700, 500, 300]
})

# %%
merge=pd.merge(prod,product,on="Product_ID")
merge
# Out:
#    Product_ID Product_Name  Price
# 0           2            B    700
# 1           3            C    500
# 2           4            D    300

# %%
Emp = pd.DataFrame({
    'Employee_ID': [1, 2, 3, 4],
    'Name': ['John', 'Alice', 'Bob', 'Emma']
})

# %%
empo= pd.DataFrame({
    'Employee_ID': [3, 4, 5, 6],
    'Salary': [50000, 60000, 70000, 80000]
})

# %%
merge=pd.merge(Emp,empo,on="Employee_ID",how="left")
merge
# Out:
#    Employee_ID   Name   Salary
# 0            1   John      NaN
# 1            2  Alice      NaN
# 2            3    Bob  50000.0
# 3            4   Emma  60000.0

# %%
col = pd.DataFrame({
    "City": ["NY", "LA", "SF"], 
    "Age": [25, 30, 35], 
    "Salary": [60000, 70000, 80000]
})

# %%
col1= pd.DataFrame({
    "City": ["NY", "LA", "CHI"], 
    "Age": [25, 30, 40], 
    "Population": [8000000, 4000000, 2700000]
})

# %%
merge = pd.merge(col, col1, on=["City", "Age"], how="inner")
merge
# Out:
#   City  Age  Salary  Population
# 0   NY   25   60000     8000000
# 1   LA   30   70000     4000000

# %%
cont = pd.DataFrame({
    "Country": ["USA", "Canada", "India"], 
    "Capital": ["Washington", "Ottawa", "Delhi"]
})

# %%
cont1 = pd.DataFrame({
    "Country": ["USA", "Canada", "UK"], 
    "Currency": ["USD", "CAD", "GBP"]
})

# %%
merge = pd.merge(cont, cont1, on="Country", how="inner")
merge
# Out:
#   Country     Capital Currency
# 0     USA  Washington      USD
# 1  Canada      Ottawa      CAD

# %%
merge = pd.merge(cont, cont1, on="Country", how="outer")
merge
# Out:
#   Country     Capital Currency
# 0  Canada      Ottawa      CAD
# 1   India       Delhi      NaN
# 2      UK         NaN      GBP
# 3     USA  Washington      USD

# %%
df.to_csv('CTR_Analysis.csv',index=False)

# %%
df.to_excel('cost1.xlsx',index=False)

# %%
df.columns
# Out:
# Index(['age', 'full_name', 'id', 'gender', 'page_visited', 'ad_displayed',
#        'ad_clicked', 'impressions', 'clicks', 'ctr', 'rate ($)',
#        'session_duration', 'device_type', 'timestamp', 'First Name',
#        'Last Name'],
#       dtype='object')

# %%
df
# Out:
#               age       full_name  id  gender   page_visited     ad_displayed  \
# city
# New_York       25        John Doe   1    Male       Homepage       Nike Shoes
# Los_Angeles    30      Jane Smith   2  Female   Product Page   Adidas T-Shirt
# Mumbai         28       Raj Patel   3    Male       Homepage        iPhone 15
# London         22      Sarah Khan   4  Female  Checkout Page      MacBook Pro
# Dubai          35       Ahmed Ali   5    Male       Homepage       Samsung TV
# Sydney         27     Emily Davis   6  Female   Product Page  Sony Headphones
# Singapore      33     Michael Lee   7    Male       Homepage      Dell Laptop
# Bangalore      24    Priya Sharma   8  Female      Cart Page       Smartwatch
# Seoul          29       David Kim   9    Male       Homepage     Gaming Mouse
# Karachi        26     Fatima Noor  10  Female   Product Page      JBL Speaker
# Mexico_City    32     Luis Garcia  11    Male       Homepage      Apple Watch
# ...

# %%
wow= df[(df["age"] > 20) & (df["age"] < 40) & (df['gender'] == "Male")]
wow
# Out:
#               age       full_name  id gender page_visited    ad_displayed  \
# city
# New_York       25        John Doe   1   Male     Homepage      Nike Shoes
# Mumbai         28       Raj Patel   3   Male     Homepage       iPhone 15
# Dubai          35       Ahmed Ali   5   Male     Homepage      Samsung TV
# Singapore      33     Michael Lee   7   Male     Homepage     Dell Laptop
# Seoul          29       David Kim   9   Male     Homepage    Gaming Mouse
# Mexico_City    32     Luis Garcia  11   Male     Homepage     Apple Watch
# Tokyo          29  Hiroshi Tanaka  13   Male     Homepage    Xbox Console
# Buenos_Aires   36    Carlos Rojas  15   Male     Homepage  Samsung Tablet
#
#               ad_clicked  impressions  clicks   ctr  rate ($)  \
# city
# New_York               1          100    0.20  10.0      0.50
# Mumbai                 1          150    1.00  20.0      1.20
# Dubai                  1           90    0.00   5.6      0.30
# ...

# %%
yup = wow.groupby("page_visited")["age"].agg(["mean", "median"])
yup
# Out:
#                 mean  median
# page_visited
# Homepage      30.875    30.5

# %%
yup= yup.sort_values(by="mean", ascending=False)
yup
# Out:
#                 mean  median
# page_visited
# Homepage      30.875    30.5

# %%
df["FullName"] = df["First Name"] + " " + df["gender"]
df
# Out:
#               age       full_name  id  gender   page_visited     ad_displayed  \
# city
# New_York       25        John Doe   1    Male       Homepage       Nike Shoes
# Los_Angeles    30      Jane Smith   2  Female   Product Page   Adidas T-Shirt
# Mumbai         28       Raj Patel   3    Male       Homepage        iPhone 15
# London         22      Sarah Khan   4  Female  Checkout Page      MacBook Pro
# Dubai          35       Ahmed Ali   5    Male       Homepage       Samsung TV
# Sydney         27     Emily Davis   6  Female   Product Page  Sony Headphones
# Singapore      33     Michael Lee   7    Male       Homepage      Dell Laptop
# Bangalore      24    Priya Sharma   8  Female      Cart Page       Smartwatch
# Seoul          29       David Kim   9    Male       Homepage     Gaming Mouse
# Karachi        26     Fatima Noor  10  Female   Product Page      JBL Speaker
# Mexico_City    32     Luis Garcia  11    Male       Homepage      Apple Watch
# ...

# %%
df[["First_Half", "Second_Half"]] = df["FullName"].str.split(" ", expand=True)
df
# Out:
#               age       full_name  id  gender   page_visited     ad_displayed  \
# city
# New_York       25        John Doe   1    Male       Homepage       Nike Shoes
# Los_Angeles    30      Jane Smith   2  Female   Product Page   Adidas T-Shirt
# Mumbai         28       Raj Patel   3    Male       Homepage        iPhone 15
# London         22      Sarah Khan   4  Female  Checkout Page      MacBook Pro
# Dubai          35       Ahmed Ali   5    Male       Homepage       Samsung TV
# Sydney         27     Emily Davis   6  Female   Product Page  Sony Headphones
# Singapore      33     Michael Lee   7    Male       Homepage      Dell Laptop
# Bangalore      24    Priya Sharma   8  Female      Cart Page       Smartwatch
# Seoul          29       David Kim   9    Male       Homepage     Gaming Mouse
# Karachi        26     Fatima Noor  10  Female   Product Page      JBL Speaker
# Mexico_City    32     Luis Garcia  11    Male       Homepage      Apple Watch
# ...

# %%
df.groupby("device_type")["full_name"].nunique()
# Out:
# device_type
# Desktop    6
# Mobile     5
# Tablet     4
# Name: full_name, dtype: int64

# %%
(df["rate ($)"] - df["rate ($)"].min()) / (df["rate ($)"].max() - df["rate ($)"].min())
# Out:
# city
# New_York        0.222222
# Los_Angeles     0.111111
# Mumbai          1.000000
# London          0.555556
# Dubai           0.000000
# Sydney          0.666667
# Singapore       0.166667
# Bangalore       0.500000
# Seoul           0.611111
# Karachi         0.222222
# Mexico_City     0.777778
# Moscow          0.555556
# Tokyo           0.444444
# Lisbon          0.277778
# Buenos_Aires    0.722222
# Name: rate ($), dtype: float64

# %%
df["age"] = df["age"].mask(df["age"] < 0, df["age"].median())
df
# Out:
#               age       full_name  id  gender   page_visited     ad_displayed  \
# city
# New_York       25        John Doe   1    Male       Homepage       Nike Shoes
# Los_Angeles    30      Jane Smith   2  Female   Product Page   Adidas T-Shirt
# Mumbai         28       Raj Patel   3    Male       Homepage        iPhone 15
# London         22      Sarah Khan   4  Female  Checkout Page      MacBook Pro
# Dubai          35       Ahmed Ali   5    Male       Homepage       Samsung TV
# Sydney         27     Emily Davis   6  Female   Product Page  Sony Headphones
# Singapore      33     Michael Lee   7    Male       Homepage      Dell Laptop
# Bangalore      24    Priya Sharma   8  Female      Cart Page       Smartwatch
# Seoul          29       David Kim   9    Male       Homepage     Gaming Mouse
# Karachi        26     Fatima Noor  10  Female   Product Page      JBL Speaker
# Mexico_City    32     Luis Garcia  11    Male       Homepage      Apple Watch
# ...

# %%
copy=df.merge(df,on="id", how="inner").head()

# %%
copy
# Out:
#    age_x full_name_x  id gender_x page_visited_x  ad_displayed_x  \
# 0     25    John Doe   1     Male       Homepage      Nike Shoes
# 1     30  Jane Smith   2   Female   Product Page  Adidas T-Shirt
# 2     28   Raj Patel   3     Male       Homepage       iPhone 15
# 3     22  Sarah Khan   4   Female  Checkout Page     MacBook Pro
# 4     35   Ahmed Ali   5     Male       Homepage      Samsung TV
#
#    ad_clicked_x  impressions_x  clicks_x  ctr_x  ...  ctr_y  rate ($)_y  \
# 0             1            100       0.2   10.0  ...   10.0         0.5
# 1             0            200       0.4    7.5  ...    7.5         0.4
# 2             1            150       1.0   20.0  ...   20.0         1.2
# 3             0            250       0.6    8.0  ...    8.0         0.8
# 4             1             90       0.0    5.6  ...    5.6         0.3
#
#   session_duration_y device_type_y          timestamp_y First Name_y  \
# ...

# %%
shop= {
    "Product ID": range(101, 111),
    "Product Name": ["Laptop", "Phone", "Tablet", "Monitor", "Keyboard", "Mouse", "Printer", "Speaker", "Headphones", "Webcam"],
    "Quantity": [5, 10, 7, 3, 8, 15, 2, 6, 12, 4],
    "Price": [800, 500, 300, 200, 50, 30, 150, 100, 70, 90]
}

# %%
pro=pd.DataFrame(shop)

# %%
pro
# Out:
#    Product ID Product Name  Quantity  Price
# 0         101       Laptop         5    800
# 1         102        Phone        10    500
# 2         103       Tablet         7    300
# 3         104      Monitor         3    200
# 4         105     Keyboard         8     50
# 5         106        Mouse        15     30
# 6         107      Printer         2    150
# 7         108      Speaker         6    100
# 8         109   Headphones        12     70
# 9         110       Webcam         4     90

# %%
pro.to_excel("shop.xlsx",index=False)

# %%
pro["Total Value"] = pro["Quantity"] * pro["Price"]

# %%
pro
# Out:
#    Product ID Product Name  Quantity  Price  Total Value
# 0         101       Laptop         5    800         4000
# 1         102        Phone        10    500         5000
# 2         103       Tablet         7    300         2100
# 3         104      Monitor         3    200          600
# 4         105     Keyboard         8     50          400
# 5         106        Mouse        15     30          450
# 6         107      Printer         2    150          300
# 7         108      Speaker         6    100          600
# 8         109   Headphones        12     70          840
# 9         110       Webcam         4     90          360

# %%
pro.to_excel("Modshop.xlsx",index=False)

# %%
student= {
    "Student ID": range(1, 11),
    "Name": ["Alice", "Bob", "Charlie", "David", "Emma", "Frank", "Grace", "Hannah", "Ian", "Jack"],
    "Grade": ["A", "B", "C", "A", "B", "C", "A", "B", "C", "A"],
    "Score": [85, 40, 75, 30, 95, 55, 20, 60, 45, 90]
}

# %%
stud = pd.DataFrame(student)

# %%
stud
# Out:
#    Student ID     Name Grade  Score
# 0           1    Alice     A     85
# 1           2      Bob     B     40
# 2           3  Charlie     C     75
# 3           4    David     A     30
# 4           5     Emma     B     95
# 5           6    Frank     C     55
# 6           7    Grace     A     20
# 7           8   Hannah     B     60
# 8           9      Ian     C     45
# 9          10     Jack     A     90

# %%
stud.to_excel("stud.xlsx",index=False)

# %%
stud["Status"]=stud["Score"].apply(lambda x: 'Pass' if x >= 50 else 'Fail')

# %%
stud
# Out:
#    Student ID     Name Grade  Score Status
# 0           1    Alice     A     85   Pass
# 1           2      Bob     B     40   Fail
# 2           3  Charlie     C     75   Pass
# 3           4    David     A     30   Fail
# 4           5     Emma     B     95   Pass
# 5           6    Frank     C     55   Pass
# 6           7    Grace     A     20   Fail
# 7           8   Hannah     B     60   Pass
# 8           9      Ian     C     45   Fail
# 9          10     Jack     A     90   Pass

# %%
stud.to_excel("Student.xlsx",index=False)

# %%
pop=pd.read_csv("Population.csv")

# %%
pop
# Out:
#        City    Country  Population    Area
# 0  New York        USA     8419600   783.8
# 1     Tokyo      Japan    13929286  2194.0
# 2    London         UK     8982000  1572.0
# 3     Paris     France     2161000   105.4
# 4    Sydney  Australia     5230330  1687.0

# %%
pop["Population Density"]=pop["Population"]/pop["Area"]
pop
# Out:
#        City    Country  Population    Area  Population Density
# 0  New York        USA     8419600   783.8        10742.026027
# 1     Tokyo      Japan    13929286  2194.0         6348.808569
# 2    London         UK     8982000  1572.0         5713.740458
# 3     Paris     France     2161000   105.4        20502.846300
# 4    Sydney  Australia     5230330  1687.0         3100.373444

# %%
pop.to_csv("ModPolution.csv",index=False)

# %%
pop.to_excel("ModPopulation.xlsx",index=False)
